# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cf5d108ddc69> in <module>()
#      14 from six.moves import urllib
#      15 from six.moves import xrange  # pylint: disable=redefined-builtin
# ---> 16 import tensorflow as tf
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
conda install numpy
# Out:
#   File "<ipython-input-2-9694d14f3072>", line 1
#     conda install numpy
#                 ^
# SyntaxError: invalid syntax

# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-1.5.0-cp36-cp36m-macosx_10_11_x86_64.whl (42.5MB)
#     100% |████████████████████████████████| 42.5MB 18kB/s  eta 0:00:01    36% |███████████▉                    | 15.7MB 14.3MB/s eta 0:00:02    48% |███████████████▍                | 20.4MB 10.2MB/s eta 0:00:03    51% |████████████████▍               | 21.8MB 4.6MB/s eta 0:00:05    94% |██████████████████████████████▏ | 40.1MB 7.5MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.12.1 in /Applications/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Collecting protobuf>=3.4.0 (from tensorflow)
#   Downloading protobuf-3.5.1-py2.py3-none-any.whl (388kB)
#     100% |████████████████████████████████| 389kB 1.5MB/s ta 0:00:011
# Collecting tensorflow-tensorboard<1.6.0,>=1.5.0 (from tensorflow)
#   Downloading tensorflow_tensorboard-1.5.0-py3-none-any.whl (3.0MB)
#     100% |████████████████████████████████| 3.0MB 285kB/s ta 0:00:011
# Collecting absl-py>=0.1.6 (from tensorflow)
#   Downloading absl-py-0.1.9.tar.gz (79kB)
#     100% |████████████████████████████████| 81kB 6.1MB/s eta 0:00:01
# Requirement already satisfied: six>=1.10.0 in /Applications/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: wheel>=0.26 in /Applications/anaconda3/lib/python3.6/site-packages (from tensorflow)
# Requirement already satisfied: setuptools in /Applications/anaconda3/lib/python3.6/site-packages (from protobuf>=3.4.0->tensorflow)
# Collecting futures>=3.1.1 (from tensorflow-tensorboard<1.6.0,>=1.5.0->tensorflow)
#   Downloading futures-3.1.1.tar.gz
# Collecting html5lib==0.9999999 (from tensorflow-tensorboard<1.6.0,>=1.5.0->tensorflow)
#   Downloading html5lib-0.9999999.tar.gz (889kB)
#     100% |████████████████████████████████| 890kB 860kB/s ta 0:00:011
# Requirement already satisfied: werkzeug>=0.11.10 in /Applications/anaconda3/lib/python3.6/site-packages (from tensorflow-tensorboard<1.6.0,>=1.5.0->tensorflow)
# Collecting bleach==1.5.0 (from tensorflow-tensorboard<1.6.0,>=1.5.0->tensorflow)
#   Downloading bleach-1.5.0-py2.py3-none-any.whl
# Collecting markdown>=2.6.8 (from tensorflow-tensorboard<1.6.0,>=1.5.0->tensorflow)
#   Downloading Markdown-2.6.11-py2.py3-none-any.whl (78kB)
#     100% |████████████████████████████████| 81kB 1.9MB/s ta 0:00:011
# Building wheels for collected packages: absl-py, futures, html5lib
#   Running setup.py bdist_wheel for absl-py ... done
#   Stored in directory: /Users/brianagearhart/Library/Caches/pip/wheels/04/f5/7c/5d4eab10ddf87dec875016e74ba289d87270a90fb2662a76fc
#   Running setup.py bdist_wheel for futures ... done
#   Stored in directory: /Users/brianagearhart/Library/Caches/pip/wheels/ad/79/48/b32521764d59b16fd1bc0ffd5862f6d3bf770c7d73ea1fb12a
#   Running setup.py bdist_wheel for html5lib ... done
#   Stored in directory: /Users/brianagearhart/Library/Caches/pip/wheels/6f/85/6c/56b8e1292c6214c4eb73b9dda50f53e8e977bf65989373c962
# Successfully built absl-py futures html5lib
# Installing collected packages: protobuf, futures, html5lib, bleach, markdown, tensorflow-tensorboard, absl-py, tensorflow
#   Found existing installation: html5lib 0.999999999
#     Uninstalling html5lib-0.999999999:
#       Successfully uninstalled html5lib-0.999999999
#   Found existing installation: bleach 2.0.0
#     Uninstalling bleach-2.0.0:
#       Successfully uninstalled bleach-2.0.0
# Successfully installed absl-py-0.1.9 bleach-1.5.0 futures-3.1.1 html5lib-0.9999999 markdown-2.6.11 protobuf-3.5.1 tensorflow-1.5.0 tensorflow-tensorboard-1.5.0

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Found and verified text8.zip
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary

# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary,
                                                            vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer[:] = data[:span]
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels

batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]],
        '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of

# %%
# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.
num_sampled = 64      # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)


graph = tf.Graph()

with graph.as_default():

  # Input data.
  train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    nce_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  loss = tf.reduce_mean(
      tf.nn.nce_loss(weights=nce_weights,
                     biases=nce_biases,
                     labels=train_labels,
                     inputs=embed,
                     num_sampled=num_sampled,
                     num_classes=vocabulary_size))

  # Construct the SGD optimizer using a learning rate of 1.0.
  optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Add variable initializer.
  init = tf.global_variables_initializer()
# Out:
# WARNING:tensorflow:From <ipython-input-8-2cd9be819b02>:57: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(
        batch_size, num_skips, skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += loss_val

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  244.329864502
# Nearest to five: hafnium, soleil, rvi, leblanc, silence, oss, emerging, freda,
# Nearest to use: smarter, violation, worshipers, rsted, correctly, shelled, wma, missiles,
# Nearest to first: hollandic, allying, barbary, citadels, ur, manuals, orchard, coerce,
# Nearest to were: bridged, formerly, revere, astral, bans, merger, stf, lachaise,
# Nearest to been: amoeboid, turmeric, turkic, haiti, republican, protects, hummingbird, progressing,
# Nearest to while: congratulate, restricting, elimination, readings, matriculation, watercolors, governess, deducted,
# Nearest to he: livonia, holborn, break, bourgeois, bawerk, overnight, mirrored, valera,
# Nearest to there: kou, years, settings, kyi, omnivores, profiles, neuronal, spherically,
# Nearest to and: mano, unregistered, stochastic, disaccharides, taps, disease, conform, cleartype,
# Nearest to four: lockheed, warrants, rearrangement, dashboard, karamazov, bilirubin, weather, negotiation,
# Nearest to his: murr, marshlands, malice, conditioned, subtract, barlow, coasts, sulfides,
# Nearest to state: banco, senate, soup, crystallographic, sovereign, steinmetz, outfitted, ihra,
# Nearest to over: finns, carcinogens, vern, bonhomme, singled, representations, augusti, rsync,
# Nearest to to: must, concurred, lowly, capitoline, metadata, admirers, genitals, roused,
# Nearest to that: cheerfully, moreau, batman, guillotine, graphs, costa, backgammon, grahame,
# Nearest to would: zoff, shared, hebrides, contenders, oxley, requisite, meant, morita,
# Average loss at step  2000 :  113.809592134
# Average loss at step  4000 :  52.9149691637
# Average loss at step  6000 :  33.4056161821
# Average loss at step  8000 :  23.5049931946
# Average loss at step  10000 :  17.6587777916
# Nearest to five: nine, one, zero, two, bckgr, seven, reginae, var,
# Nearest to use: agave, annual, rsted, correctly, violation, homo, vs, split,
# Nearest to first: ur, rough, instructs, recursive, on, across, hobby, duty,
# Nearest to were: are, has, bans, surrounding, although, pompey, that, formerly,
# Nearest to been: amoeboid, confederacy, turkic, haiti, ranged, old, powerbook, protects,
# Nearest to while: markov, album, survivors, readings, balls, elimination, followers, columbia,
# Nearest to he: brakes, it, bourgeois, durant, bawerk, there, reprint, break,
# Nearest to there: exhibitions, victoriae, also, settings, coke, tax, advancing, years,
# Nearest to and: in, of, UNK, or, reginae, coke, by, gland,
# Nearest to four: seven, victoriae, zero, eight, one, three, nine, reginae,
# Nearest to his: the, conditioned, archibald, reginae, a, linux, golden, bckgr,
# Nearest to state: sovereign, senate, soup, argon, frames, colombia, unicode, frau,
# Nearest to over: victoriae, himself, staging, seven, resolution, verse, bckgr, angeles,
# Nearest to to: in, and, atheism, reginae, nine, of, removed, condition,
# Nearest to that: which, blockade, secret, pa, moreau, stroke, trade, rotate,
# Nearest to would: shared, defensive, one, oral, pogrom, delos, hebrides, meant,
# Average loss at step  12000 :  13.7906787931
# Average loss at step  14000 :  11.7074708614
# Average loss at step  16000 :  9.96548946798
# Average loss at step  18000 :  8.5371601482
# Average loss at step  20000 :  8.04393985856
# Nearest to five: nine, zero, seven, eight, six, two, three, four,
# Nearest to use: agouti, agave, rsted, correctly, violation, annual, petition, homo,
# Nearest to first: rough, ur, instructs, on, recursive, duty, descendents, across,
# Nearest to were: are, is, has, was, grotto, and, although, dasyprocta,
# Nearest to been: by, had, was, amoeboid, confederacy, haiti, dasyprocta, ranged,
# Nearest to while: elimination, album, haran, followers, survivors, dasyprocta, readings, is,
# Nearest to he: it, there, bourgeois, household, they, not, durant, brakes,
# Nearest to there: he, it, exhibitions, also, who, victoriae, modifications, and,
# Nearest to and: or, of, in, agouti, dasyprocta, operatorname, reginae, circ,
# Nearest to four: eight, seven, nine, six, zero, three, two, five,
# Nearest to his: the, dasyprocta, its, s, her, circ, a, reginae,
# Nearest to state: senate, acapulco, sovereign, agouti, alamanni, soup, gurps, frames,
# Nearest to over: seven, victoriae, to, five, truetype, two, himself, nn,
# Nearest to to: and, circ, operatorname, nine, for, in, packets, must,
# Nearest to that: which, and, blockade, who, secret, smooth, left, pa,
# Nearest to would: hebrides, had, delos, shared, may, syllabic, outta, oral,
# Average loss at step  22000 :  7.08395685112
# Average loss at step  24000 :  6.85945728719
# Average loss at step  26000 :  6.73063312054
# Average loss at step  28000 :  6.35320331633
# Average loss at step  30000 :  5.91836130035
# Nearest to five: eight, six, four, seven, zero, nine, three, two,
# Nearest to use: agouti, agave, rsted, petition, correctly, violation, annual, pencil,
# Nearest to first: hollandic, rough, ur, instructs, descendents, allying, across, colors,
# Nearest to were: are, was, is, has, grotto, have, by, although,
# Nearest to been: by, had, was, confederacy, amoeboid, ranged, be, haiti,
# Nearest to while: and, followers, elimination, album, survivors, haran, is, restricting,
# Nearest to he: it, there, they, household, who, zero, bourgeois, almighty,
# Nearest to there: it, he, exhibitions, also, who, they, and, victoriae,
# Nearest to and: or, agouti, in, one, reginae, dasyprocta, operatorname, of,
# Nearest to four: eight, seven, six, five, three, two, nine, zero,
# Nearest to his: the, her, s, its, their, dasyprocta, circ, amazonas,
# Nearest to state: senate, acapulco, sovereign, alamanni, agouti, gurps, daughters, anchoring,
# Nearest to over: seven, rsync, trinomial, to, five, victoriae, absorptive, nn,
# Nearest to to: nine, circ, for, operatorname, must, in, switchable, can,
# Nearest to that: which, blockade, this, who, and, but, ambrose, secret,
# Nearest to would: may, had, hebrides, to, delos, shared, outta, could,
# Average loss at step  32000 :  5.97572553897
# Average loss at step  34000 :  5.73535584009
# Average loss at step  36000 :  5.79631249845
# Average loss at step  38000 :  5.5488602643
# Average loss at step  40000 :  5.24983199012
# Nearest to five: six, four, three, eight, seven, zero, two, nine,
# Nearest to use: agouti, agave, rsted, petition, abakan, pencil, reification, correctly,
# Nearest to first: last, rough, instructs, descendents, hollandic, ur, rewarded, recursive,
# Nearest to were: are, was, have, is, grotto, has, be, by,
# Nearest to been: by, was, be, had, were, confederacy, ranged, haiti,
# Nearest to while: elimination, followers, is, album, readings, dasyprocta, restricting, markov,
# Nearest to he: it, there, they, who, household, bourgeois, she, zero,
# Nearest to there: it, he, exhibitions, they, also, who, neuronal, in,
# Nearest to and: or, agouti, zero, in, but, otimes, reginae, operatorname,
# Nearest to four: six, eight, three, five, seven, zero, two, one,
# Nearest to his: her, their, the, its, dasyprocta, s, circ, a,
# Nearest to state: senate, acapulco, sovereign, agouti, gurps, alamanni, recitative, frames,
# Nearest to over: five, rsync, truetype, vault, albury, victoriae, trinomial, seven,
# Nearest to to: must, nine, circ, operatorname, switchable, zero, for, can,
# Nearest to that: which, this, but, blockade, it, who, smooth, reginae,
# Nearest to would: may, hebrides, will, can, could, had, to, delos,
# Average loss at step  42000 :  5.38987338424
# Average loss at step  44000 :  5.25941319191
# Average loss at step  46000 :  5.25286501145
# Average loss at step  48000 :  5.22805252588
# Average loss at step  50000 :  4.95994190037
# Nearest to five: six, four, three, eight, seven, two, zero, kapoor,
# Nearest to use: agouti, kapoor, agave, rsted, pencil, petition, abakan, rims,
# Nearest to first: last, second, rough, instructs, rewarded, descendents, plagiarized, across,
# Nearest to were: are, was, have, is, grotto, has, had, kapoor,
# Nearest to been: be, by, had, was, ranged, confederacy, were, haiti,
# Nearest to while: and, followers, kapoor, elimination, dasyprocta, album, readings, markov,
# Nearest to he: it, they, there, who, she, household, bourgeois, stasi,
# Nearest to there: it, they, he, also, exhibitions, who, now, which,
# Nearest to and: or, kapoor, but, four, agouti, eight, six, reginae,
# Nearest to four: six, three, five, eight, seven, two, one, zero,
# Nearest to his: their, her, the, its, s, dasyprocta, archibald, circ,
# Nearest to state: senate, acapulco, sovereign, agouti, gurps, alamanni, daughters, hadley,
# Nearest to over: three, seven, albury, nn, victoriae, truetype, kapoor, five,
# Nearest to to: must, circ, operatorname, nine, will, for, and, would,
# Nearest to that: which, this, but, blockade, it, where, finish, mama,
# Nearest to would: may, will, can, could, hebrides, to, must, upward,
# Average loss at step  52000 :  5.0735032208
# Average loss at step  54000 :  5.20352726173
# Average loss at step  56000 :  5.0339365952
# Average loss at step  58000 :  5.07166149032
# Average loss at step  60000 :  4.96524320757
# Nearest to five: six, four, three, eight, seven, nine, two, zero,
# Nearest to use: agouti, kapoor, agave, ursus, rsted, michelob, pencil, petition,
# Nearest to first: last, second, descendents, rough, rewarded, instructs, ursus, plagiarized,
# Nearest to were: are, was, have, had, grotto, is, kapoor, be,
# Nearest to been: be, was, had, by, ranged, were, confederacy, become,
# Nearest to while: and, kapoor, followers, elimination, when, is, dasyprocta, five,
# Nearest to he: it, they, who, there, she, household, bourgeois, kapoor,
# Nearest to there: it, they, he, also, who, exhibitions, now, which,
# Nearest to and: or, kapoor, but, agouti, ursus, reginae, in, of,
# Nearest to four: six, five, eight, three, two, seven, nine, zero,
# Nearest to his: their, her, its, the, dasyprocta, s, archibald, them,
# Nearest to state: senate, acapulco, sovereign, agouti, gurps, alamanni, ursus, recitative,
# Nearest to over: five, ursus, nn, albury, victoriae, six, kapoor, three,
# Nearest to to: will, must, nine, operatorname, would, circ, ursus, can,
# Nearest to that: which, this, but, ursus, blockade, balochistan, where, however,
# Nearest to would: may, will, can, could, to, should, hebrides, must,
# Average loss at step  62000 :  5.02880646014
# Average loss at step  64000 :  4.82653060669
# Average loss at step  66000 :  4.6034201231
# Average loss at step  68000 :  4.98735162413
# Average loss at step  70000 :  4.89872296762
# Nearest to five: four, six, three, eight, seven, zero, nine, two,
# Nearest to use: agouti, thaler, kapoor, agave, microcebus, ursus, rsted, pencil,
# Nearest to first: last, second, rough, thaler, descendents, rewarded, instructs, ursus,
# Nearest to were: are, was, have, had, grotto, be, pompey, kapoor,
# Nearest to been: be, was, by, had, become, were, ranged, confederacy,
# Nearest to while: and, kapoor, when, followers, where, or, elimination, dasyprocta,
# Nearest to he: it, she, they, who, there, household, bourgeois, stasi,
# Nearest to there: it, they, he, who, exhibitions, now, also, which,
# Nearest to and: or, kapoor, but, ursus, agouti, mico, thaler, operatorname,
# Nearest to four: six, five, eight, three, seven, two, nine, one,
# Nearest to his: their, her, its, the, dasyprocta, s, them, amazonas,
# Nearest to state: senate, acapulco, microcebus, gurps, agouti, callithrix, sovereign, ursus,
# Nearest to over: five, nn, ursus, six, albury, victoriae, microcebus, vault,
# Nearest to to: must, will, would, circ, operatorname, switchable, ursus, nine,
# Nearest to that: which, this, upanija, blockade, however, but, ursus, balochistan,
# Nearest to would: will, may, can, could, should, must, to, hebrides,
# Average loss at step  72000 :  4.75681779456
# Average loss at step  74000 :  4.80883707881
# Average loss at step  76000 :  4.72888156343
# Average loss at step  78000 :  4.79065232956

# %%
# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
